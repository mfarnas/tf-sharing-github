# %% [markdown]
# This notebook is used to scrape news from https://www.space.com/news.
# A function is provided to:
# * retrieve the space.com news page,
# * extract the news stories, and
# * print out the headline, author, synopsis, and date and time for each story.
#
# Then, the spider follows the "Next" link at the bottom of the page to scrape more news stories in the following pages.
#
# Note: Chrome Developer tools (Ctrl + Shift + I, or More tools --> Developer tools) is used to examine the structure of the page to find the HTML for the articles, then requests and BeautifulSoup are used for data extraction.

# %%
import requests
from bs4 import BeautifulSoup
from random import randint
from IPython.core.display import clear_output
from warnings import warn
import time

# %%
def process_newspage(soup):
  headlines_html = soup.select('.content > header > .article-name')
  headline_list = [headline.get_text().strip() for headline in headlines_html]

  authors_html = soup.select('.by-author > span')
  author_list = [author.get_text().strip() for author in authors_html]

  time_html = soup.select('time')
  datetime_list = [time['datetime'] for time in time_html]

  synopses_html = soup.select('.synopsis')
  synopsis_list = [synopsis.get_text().strip() for synopsis in synopses_html]

  news = [{'headline': headline, 'author': author, 'datetime': datetime, 'synopsis': synopsis} for headline, author, datetime, synopsis in zip(headline_list, author_list, datetime_list, synopsis_list)]

  return news

# %%
start = time.time()
  
headers = {'user-agent': 'newsscraper - Thinkful project (example@gmail.com)'}

request_count = 0
max_request = 8
page_number = 1
has_next_page = True

news_allpages_compiled = {}

while has_next_page and request_count <= max_request:
  clear_output(wait = True)

  url = 'https://www.space.com/news/{}'.format(page_number)
  response = requests.get(url, headers = headers)
  key = 'page {}'.format(page_number)

  if response.ok:
    data = response.text
    soup = BeautifulSoup(data, 'html.parser')
    news = process_newspage(soup)
    news_allpages_compiled[key] = news
  
  else:
    # display warning if there is any problem
    warn('Request #: {}, Failed with status code: {}'.format(request_count, response.status_code))
  
  # go to sleep for 1-5 seconds before making the next request
  time.sleep(randint(1,5))
  
  # output some logs for monitoring
  end = time.time()
  elapsed_time = end - start
  print('Requests: {}, Frequency: {} request/s, {} jobs processed.'.format(request_count, request_count/elapsed_time, len(news)))
  
  # prepare for next iteration
  page_number += 1
  request_count += 1

print('Requests: {}, Frequency: {} request/s, {} jobs processed.'.format(request_count, request_count/elapsed_time, len(news)))
print('Scraping complete')
news_allpages_compiled
# Out:
# Requests: 8, Frequency: 0.23098260583078667 request/s, 20 jobs processed.
# Requests: 9, Frequency: 0.259855431559635 request/s, 20 jobs processed.
# Scraping complete
# {'page 1': [{'author': 'Hanneke Weitering',
#    'datetime': '2020-02-01T13:23:00Z',
#    'headline': 'On This Day in Space: Feb. 1, 2003: Space shuttle Columbia disaster',
#    'synopsis': 'On Feb. 1, 2003, the space shuttle Columbia broke apart as it returned to Earth after spending more than two weeks in space. See how it happened in our On This Day in Space video series!'},
#   {'author': 'Chris Vaughan',
#    'datetime': '2020-02-01T13:10:24Z',
#    'headline': 'Best night sky events of February 2020 (stargazing maps)',
#    'synopsis': "See what's up in the night sky for February 2020, including stargazing events and the moon's phases, in this Space.com gallery courtesy of Starry Night Software."},
#   {'author': 'Joe Rao',
#    'datetime': '2020-02-01T13:10:16Z',
#    'headline': "The brightest planets in February's night sky: How to see them (and when)",
#    'synopsis': "Here's how to see planets visible in February's night sky."},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-02-01T13:03:42Z',
#    'headline': "Super Bowl 2020: Here's all the space-themed commercials so far",
#    'synopsis': "This year's Super Bowl commercials promise to be out of this world."},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-02-01T13:00:38Z',
#    'headline': "Walmart's Super Bowl 2020 commercial recruits Martians, 'Star Trek,' Lego and sci-fi icons",
#    'synopsis': 'Who knew that something as mundane as grocery pickup could be this relevant to sci-fi space exploration?'},
#   {'author': 'Joe Rao',
#    'datetime': '2020-01-31T22:57:39Z',
#    'headline': "How to see the 'elusive planet' Mercury in the night sky in February",
#    'synopsis': 'Mercury is often cited as the most difficult of the naked-eye planets to see due its proximity to the sun, but there are times during the year when Mercury can be surprisingly easy to spot.'},
#   {'author': 'Tariq Malik',
#    'datetime': '2020-01-31T19:39:33Z',
#    'headline': "Live Science launches the 'Life's Little Mysteries' podcast! Get ready for far-out science questions (and answers)",
#    'synopsis': "It's here, the Life's Little Mysteries podcast has launched and we will answer all of your questions, big and small."},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-31T17:00:54Z',
#    'headline': "Amazon Prime's 'Troop Zero' shows inspiring effect of Voyager's 'Golden Record' on kids",
#    'synopsis': 'The new movie "Troop Zero" fictionalizes the cultural impact of the Voyager 1 and 2 spacecraft\'s famous message.'},
#   {'author': 'Hanneke Weitering',
#    'datetime': '2020-01-31T16:54:46Z',
#    'headline': 'Cygnus cargo ship leaves International Space Station, begins new mission in orbit',
#    'synopsis': "Northrop Grumman's Cygnus NG-12 cargo spacecraft departed the International Space Station today (Jan. 31) and will spend the next month completing a secondary mission before meeting its fiery demise."},
#   {'author': 'Space.com Staff',
#    'datetime': '2020-01-31T16:16:02Z',
#    'headline': 'Pictures from Space! Our Image of the Day',
#    'synopsis': "Three NASA astronauts peer through the windows of the International Space Station's Cupola observatory in this view from one of the station's external cameras."},
#   {'author': 'Rafi Letzter',
#    'datetime': '2020-01-31T16:00:16Z',
#    'headline': 'Physicists: Ancient life might have escaped Earth and journeyed to alien stars',
#    'synopsis': 'A pair of researchers presented a wild new theory in a new paper.'},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-31T15:00:35Z',
#    'headline': 'Bill Nye, bubbles and water on Mars to land at Super Bowl 2020',
#    'synopsis': "Bill Nye to enjoy some bubbles and contemplate humanity's future on Mars this Super Bowl LIV."},
#   {'author': 'Space.com Staff',
#    'datetime': '2020-01-31T14:14:37Z',
#    'headline': 'Watch live! Cygnus cargo spacecraft leaves the International Space Station',
#    'synopsis': 'A Northrop Grumman Cygnus cargo spacecraft will depart the International Space Station and burn up in the atmosphere. It is scheduled to be released at 9:35 a.m. EST (1435 GMT).'},
#   {'author': 'Samantha Mathewson',
#    'datetime': '2020-01-31T12:11:14Z',
#    'headline': 'Historic dual-habitat mock Mars mission begins in the Utah desert',
#    'synopsis': 'A new crew has arrived at the Mars Desert Research Station for a two-week dual-habitat simulation.'},
#   {'author': 'Meghan Bartels',
#    'datetime': '2020-01-31T12:01:02Z',
#    'headline': "NASA's Spitzer Space Telescope is no more. Here's what's next for infrared astronomy.",
#    'synopsis': 'The best infrared eye in the universe has closed, and scientists will need to wait at least a year before any similar instrument is at work again.'},
#   {'author': 'JoAnna Wendel',
#    'datetime': '2020-01-31T11:54:20Z',
#    'headline': 'NASA unveils 16 payloads that private lunar landers will take to the moon',
#    'synopsis': "The science gear will fly aboard robotic landers built by two private companies: Pittsburgh's Astrobotic and Houston's Intuitive Machines."},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-31T11:49:58Z',
#    'headline': "Sci-fi author Andy Weir says NASA didn't name 'Artemis' moon program after his book",
#    'synopsis': 'Andy Weir, the best-selling author of "The Martian" and "Artemis," was just as surprised as the rest of us when NASA gave its new crewed moon landing program a familiar name: "Artemis."'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-31T03:28:03Z',
#    'headline': 'Rocket Lab launches satellite for US spysat agency, guides booster back to Earth',
#    'synopsis': "Rocket Lab just launched its first payload for the United States' spysat agency — and took another big step toward rocket reusability in the process."},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-30T21:35:02Z',
#    'headline': 'Japanese billionaire calls off girlfriend contest for moon trip on SpaceX Starship',
#    'synopsis': 'The first woman to the moon will no longer be the winner of a billionaire\'s "girlfriend contest."'},
#   {'author': 'Jordan Gerblick',
#    'datetime': '2020-01-30T21:17:21Z',
#    'headline': 'Life-size Baby Yoda replica opens for pre-order, immediately crashes website',
#    'synopsis': 'Sideshow has unveiled a frighteningly life-like Baby Yoda figurine is available for pre-order – and, naturally, their website immediately crashed following the announcement.'}],
#  'page 2': [{'author': 'Scott Snowden',
#    'datetime': '2020-01-30T21:16:30Z',
#    'headline': "'Star Trek: Picard' gets more 'engaging' in episode 2",
#    'synopsis': 'Episode 2 of "Star Trek: Picard" on CBS All Access is worthy second installment and offers hope that the series will continue to improve, rather than degrade in quality.'},
#   {'author': 'Charles Q. Choi',
#    'datetime': '2020-01-30T20:40:49Z',
#    'headline': 'Space-time is swirling around a dead star, proving Einstein right again',
#    'synopsis': "The way the fabric of space and time swirls in a cosmic whirlpool around a dead star has confirmed yet another prediction from Einstein's theory of general relativity, a new study finds."},
#   {'author': 'Hanneke Weitering',
#    'datetime': '2020-01-30T18:49:46Z',
#    'headline': "SpaceX just destroyed a huge tank for its Starship on purpose. Here's the video!",
#    'synopsis': "A prototype of SpaceX's Starship Mars-colonization spacecraft blew its lid in a crucial pressure test late Tuesday night (Jan. 28)."},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-30T15:47:57Z',
#    'headline': 'NASA authorization bill advances in House. Proposed limits on commercial partners spur concern',
#    'synopsis': "NASA's authorization bill will proceed further through the House of Representatives without, so far, any amendments addressing major concerns raised about its effect on lunar exploration."},
#   {'author': 'Robert Z. Pearlman',
#    'datetime': '2020-01-30T15:00:01Z',
#    'headline': "Astronaut Nicole Stott on 'making space' in Olay Super Bowl ad",
#    'synopsis': '"Operation \'Make Space for Women\' is ready for lift off." Astronaut Nicole Stott spoke about appearing in Olay\'s new space-themed Super Bowl LIV commercial.'},
#   {'author': 'Tariq Malik',
#    'datetime': '2020-01-30T13:09:13Z',
#    'headline': 'NASA honors astronauts lost in 3 space tragedies with Day of Remembrance',
#    'synopsis': ''},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-30T12:10:55Z',
#    'headline': 'No satellite crash: 2 pieces of space junk whiz safely by each other over Pittsburgh',
#    'synopsis': 'Satellite operators, and everyone else who wants a safe and sustainable space environment, dodged a bullet Wednesday evening (Jan. 29).'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-30T12:03:16Z',
#    'headline': 'Rocket Lab will launch a mission for US spysat agency tonight. Watch it live!',
#    'synopsis': 'Rocket Lab will launch its first mission for the U.S. National Reconnaissance Office tonight (Jan. 30), and you can watch the liftoff live.'},
#   {'author': 'Doris Elin Urrutia',
#    'datetime': '2020-01-30T12:01:50Z',
#    'headline': 'Farewell, Spitzer Space Telescope! NASA shuts down prolific observatory.',
#    'synopsis': "One of NASA's great telescopes will go offline today (Jan. 30) after 16.5 years of observations that helped to paint a more complete picture of the universe."},
#   {'author': 'Marshall Honorof',
#    'datetime': '2020-01-30T11:58:32Z',
#    'headline': "How to catch every reference in 'Star Trek: Picard' episode 1 'Remembrance'",
#    'synopsis': "Here's a list of episodes and movies to watch if you want to understand every last detail in Star Trek: Picard: Remembrance."},
#   {'author': 'Yasemin Saplakoglu',
#    'datetime': '2020-01-30T11:51:10Z',
#    'headline': "Glowing green 'dunes' in the sky mesmerized skygazers. They turned out to be a new kind of aurora.",
#    'synopsis': 'The pattern of light was unfamiliar and strangely perfect, reaching out toward the horizon like a set of celestial sand dunes.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-30T11:49:25Z',
#    'headline': "The Spitzer Space Telescope's greatest exoplanet discoveries of all time",
#    'synopsis': "One of Spitzer's greatest contributions was what it told us about alien worlds."},
#   {'author': 'Nola Taylor Redd',
#    'datetime': '2020-01-29T22:48:27Z',
#    'headline': "World's largest solar telescope produces never-before-seen image of our star",
#    'synopsis': "Hawaii's Inouye Solar Telescope has released its first detailed image of the sun."},
#   {'author': 'Joe Rao',
#    'datetime': '2020-01-29T22:45:41Z',
#    'headline': "2 old satellites will buzz each other over Pittsburgh tonight. Here's how to see the space junk.",
#    'synopsis': "The potential (but unlikely) collision of two old satellites will be visible in the eastern U.S. today (Jan. 29) at at 6:39 p.m. EST. Here's how to see it."},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-29T22:00:59Z',
#    'headline': "'Star Trek's' Wil Wheaton narrates new 'The Martian' audiobook by Andy Weir",
#    'synopsis': 'Fans of "Star Trek" and "The Martian" — the hit novel about fictional astronaut Mark Watney being stranded on the Red Planet — have an exciting audiobook to look forward to.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-29T20:30:53Z',
#    'headline': "The odds of a NASA, US military satellite crash above Pittsburgh have gone up. (They're still low.)",
#    'synopsis': "The odds of a space-junk crash Wednesday evening (Jan.29) aren't as slim as we had thought, it turns out."},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-29T17:58:17Z',
#    'headline': "'Assembler' robots could build solar arrays and more on the moon",
#    'synopsis': "Could robots help power NASA's quest to return humans to the moon?"},
#   {'author': 'Meghan Bartels',
#    'datetime': '2020-01-29T17:02:51Z',
#    'headline': 'Voyager 2 just missed a spin in interstellar space. But it should be fine, NASA says.',
#    'synopsis': "NASA's venerable Voyager 2 spacecraft is recovering from a glitch, but engineers are confident that the probe will be back to normal science operations soon, the agency said."},
#   {'author': 'Doris Elin Urrutia',
#    'datetime': '2020-01-29T16:00:49Z',
#    'headline': "'Vampire' star sparks brilliant 'super-outburst' while gorging on its neighbor",
#    'synopsis': 'This rare finding was made by "accident," according to the research team that found the super-outburst.'},
#   {'author': 'Meghan Bartels',
#    'datetime': '2020-01-29T15:27:25Z',
#    'headline': "NASA's James Webb Space Telescope may miss March 2021 launch, GAO report says",
#    'synopsis': "NASA's much-delayed space telescope just got a scathing report card from a government agency."}],
#  'page 3': [{'author': 'Meghan Bartels',
#    'datetime': '2020-01-29T15:00:40Z',
#    'headline': 'NASA is turning off the Spitzer Space Telescope. Its infrared eye changed our view of the universe.',
#    'synopsis': 'NASA is bidding goodbye to a premier space telescope, one that let scientists peer into the dusty corners of the universe.'},
#   {'author': 'Amy Thompson',
#    'datetime': '2020-01-29T14:38:37Z',
#    'headline': 'SpaceX launches 60 new Starlink satellites, sticks rocket landing at sea',
#    'synopsis': 'SpaceX successfully launched its fourth batch of Starlink satellites into orbit and nailed a rocket landing today (Jan. 29) following days of weather delays for the mission.'},
#   {'author': 'Charles Q. Choi',
#    'datetime': '2020-01-29T12:00:21Z',
#    'headline': "Jupiter and Saturn may leave marks on the sun's corpse",
#    'synopsis': 'The outer layers of superdense stellar remnants known as white dwarfs may often possess the remains of giant planets, a new study suggests.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-29T11:30:10Z',
#    'headline': 'NASA scientist gets new Earth-observation satellite named after him, a rare honor',
#    'synopsis': "An Earth-observation satellite scheduled to launch this fall was just named after Michael Freilich, who headed NASA's Earth Science division from 2006 to 2019."},
#   {'author': 'Meghan Bartels',
#    'datetime': '2020-01-29T11:00:27Z',
#    'headline': 'NASA spacecraft breaks its own record with another swing by the sun',
#    'synopsis': "NASA's Parker Solar Probe took one step closer to the sun Wednesday (Jan. 29) when it executed its fourth flyby of our star."},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-29T10:25:22Z',
#    'headline': 'Potential collision of old NASA space telescope and a defunct US satellite would spawn new debris swarm',
#    'synopsis': "Let's hope that today's space-junk encounter is just a near miss as predicted, because a smashup would be pretty messy."},
#   {'author': 'Amy Thompson',
#    'datetime': '2020-01-29T10:15:32Z',
#    'headline': "SpaceX is launching 60 more Starlink satellites today. Here's how to watch live.",
#    'synopsis': 'The private spaceflight company SpaceX will launch 60 new Starlink satellites to join its growing broadband internet megaconstellation in orbit Wednesday (Jan. 29), and you can watch it live online.'},
#   {'author': 'Space.com Staff',
#    'datetime': '2020-01-28T21:47:15Z',
#    'headline': "Gallery: The infrared universe seen by NASA's Spitzer Space Telescope",
#    'synopsis': "See images from NASA's infrared Spitzer Space Telescope."},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-28T20:15:55Z',
#    'headline': "Alien investigation series 'Project Blue Book' shows more weird encounters in Season 2",
#    'synopsis': '"Project Blue Book," the hit television docudrama about the U.S. military\'s investigations into aliens more than 50 years ago, is back for Season 2.'},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-28T19:57:00Z',
#    'headline': "'The Rentals' release tribute song for astronauts killed in the Challenger shuttle disaster",
#    'synopsis': ''},
#   {'author': 'Rafi Letzter',
#    'datetime': '2020-01-28T18:30:29Z',
#    'headline': '2 satellites will narrowly avoid colliding at 32,800 mph over Pittsburgh on Wednesday',
#    'synopsis': 'A collision would create a debris belt that would endanger spacecraft worldwide.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-28T17:26:10Z',
#    'headline': "Jeri Ryan brings Borg back to 'Star Trek Online' as well as 'Picard'",
#    'synopsis': 'While Trekkies worldwide exult in the return of Jeri Ryan to "Star Trek: Picard," the actor is also coming back to "Star Trek Online" — a long-running game in the Trek universe.'},
#   {'author': 'Hanneke Weitering',
#    'datetime': '2020-01-28T17:22:15Z',
#    'headline': "The 'evening star' Venus swings by the crescent moon today. Here's how to see it.",
#    'synopsis': 'Tonight (Jan. 28), you can catch the crescent moon make a close approach to Venus in the evening sky.'},
#   {'author': 'Samantha Mathewson',
#    'datetime': '2020-01-28T17:21:20Z',
#    'headline': "NASA's Parker Solar Probe hears whispers of solar wind",
#    'synopsis': 'Streams of plasma from the sun create "chirping" and "whistling" noises heard by NASA\'s Parker Solar Probe.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-28T12:04:43Z',
#    'headline': 'The International Space Station is getting a commercial module',
#    'synopsis': 'NASA has picked Houston-based company Axiom Space to build at least one habitable private module that will be attached to the orbiting lab, the space agency announced Monday (Jan. 27).'},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-28T12:03:46Z',
#    'headline': "Hottest known exoplanet is so hot, it's tearing its molecules apart",
#    'synopsis': "The hottest exoplanet ever found is so infernally hot that it's ripping apart hydrogen molecules in its atmosphere, astronomers have found."},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-28T11:59:48Z',
#    'headline': "European Solar Orbiter will give us our first look at the sun's poles",
#    'synopsis': 'Scientists are about to get their first-ever good looks at the poles of the sun, which could be key to solving some long-standing solar mysteries.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-28T11:57:37Z',
#    'headline': "Proposed House bill pushes NASA's crewed moon landing back to 2028",
#    'synopsis': 'But the bill is still a long way from becoming law.'},
#   {'author': 'Hanneke Weitering',
#    'datetime': '2020-01-27T23:36:31Z',
#    'headline': 'Space calendar 2020: Rocket launches, sky events, missions & more!',
#    'synopsis': "Here's a guide to all the rocket launches and astronomical events in 2020, as well as milestones for space missions, anniversaries and conferences."},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-27T18:37:55Z',
#    'headline': 'European scientists are taking a mock moon mission in Hawaii right now',
#    'synopsis': 'A crew of researchers prepared to leave "Mars" this past Saturday (Jan. 18) as another crew arrived, ready to explore the "moon."'}],
#  'page 4': [{'author': 'Amy Thompson',
#    'datetime': '2020-01-27T17:57:09Z',
#    'headline': 'Rocket glitch delays launch of European Solar Orbiter to Feb. 7',
#    'synopsis': "The launch of the European Space Agency's (ESA) Solar Orbiter spacecraft has been delayed two days after engineers discovered a rocket issue during preflight testing."},
#   {'author': 'Robert Z. Pearlman',
#    'datetime': '2020-01-27T17:29:07Z',
#    'headline': "Fallen SpaceShipTwo pilot's name added to Space Mirror Memorial",
#    'synopsis': 'A name has been added the U.S. memorial for fallen astronauts, honoring the first commercial spacecraft pilot to die in the pursuit of opening outer space to the public.'},
#   {'author': 'Amy Thompson',
#    'datetime': '2020-01-27T15:20:46Z',
#    'headline': 'SpaceX postpones launch of Starlink satellite fleet due to bad weather',
#    'synopsis': 'SpaceX called off the next launch for its Starlink megaconstellation of internet satellites due to bad weather Monday (Jan. 27), postponing the flight for 24 hours.'},
#   {'author': 'Meghan Bartels',
#    'datetime': '2020-01-27T11:27:22Z',
#    'headline': 'Pluto and Titan are surprisingly hazy, but scientists are fuzzy on exactly why',
#    'synopsis': "NASA's New Horizons mission turned Pluto from a fuzzy blob into a detailed, geophysically complex world. But it's still a little fuzzy, as it turns out."},
#   {'author': 'Leonard David',
#    'datetime': '2020-01-27T11:27:18Z',
#    'headline': "NASA's Mars 2020 rover photobombed by mysterious 'High Bay Bob' in sunglasses",
#    'synopsis': ''},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-27T11:23:49Z',
#    'headline': 'These twin rovers might explore the moon together one day',
#    'synopsis': "Astronauts aren't the only ones who will have to work together on future crewed missions."},
#   {'author': 'Yasemin Saplakoglu',
#    'datetime': '2020-01-27T11:00:17Z',
#    'headline': 'Why physicists are determined to prove Galileo and Einstein wrong',
#    'synopsis': "Physicists dropped objects on a satellite for two years to test Galileo's theory of falling objects."},
#   {'author': 'Rafi Letzter',
#    'datetime': '2020-01-26T19:05:58Z',
#    'headline': 'Mysterious particles spewing from Antarctica defy physics',
#    'synopsis': "What's making these things fly out of the frozen continent?"},
#   {'author': 'Scott Snowden',
#    'datetime': '2020-01-26T16:16:01Z',
#    'headline': "Netflix's futuristic sci-fi series 'Altered Carbon' returns with season two next month",
#    'synopsis': '"Altered Carbon," the futuristic sci-fi series from Netflix, is set to return on Feb. 27 for an eight-episode second season.'},
#   {'author': 'Tariq Malik',
#    'datetime': '2020-01-26T15:49:33Z',
#    'headline': 'Firefly Aerospace rocket engine test ends in fire (video)',
#    'synopsis': 'Firefly Aerospace is opening up about a fire that broke out during a recent rocket engine test, releasing video of the event as it investigates the cause of the failure.'},
#   {'author': 'Newsarama Staff',
#    'datetime': '2020-01-26T15:00:22Z',
#    'headline': "'Star Wars: The Clone Wars' final season trailer, debut date revealed",
#    'synopsis': 'The animated series returns on Disney Plus next month.'},
#   {'author': 'Joe Rao',
#    'datetime': '2020-01-26T12:53:16Z',
#    'headline': 'Spot Auriga the charioteer (and goat tender) in the winter sky',
#    'synopsis': 'Auriga is one of those star patterns whose exact origin is a hopeless mix of antique conceptions.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-26T12:47:06Z',
#    'headline': "Swan Nebula 'star factory' reveals protostar treasure to NASA's flying telescope",
#    'synopsis': "SOFIA, the airplane-mounted telescope, gathered data that is changing astronomers' understanding of a massive star factory."},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-26T12:36:38Z',
#    'headline': 'NASA animation shows global effects of Australia wildfires, hurricanes and more',
#    'synopsis': 'A new animation from NASA shows the impact of those fires and other extreme disasters around the world from the past year.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-25T20:28:56Z',
#    'headline': "Astronauts complete 4-spacewalk marathon to fix space station's $2 billion antimatter detector",
#    'synopsis': 'It took four entire spacewalks to fix.'},
#   {'author': 'Tariq Malik',
#    'datetime': '2020-01-25T16:17:40Z',
#    'headline': "Rocket Lab's 1st launch of 2020 is for the National Reconnaissance Office, the US spysat agency",
#    'synopsis': "The company's also building a new launchpad and expanding its headquarters."},
#   {'author': 'Tariq Malik',
#    'datetime': '2020-01-25T14:11:43Z',
#    'headline': "Trump unveils new Space Force logo (yes, it looks like something from 'Star Trek')",
#    'synopsis': "But there's more to the story."},
#   {'author': 'Tariq Malik',
#    'datetime': '2020-01-25T12:55:17Z',
#    'headline': 'Google doodle celebrates lunar new year as astronaut photographs Beijing from space',
#    'synopsis': 'The Year of the Rat has officially begun and Google is celebrating the start of the Lunar New Year with an adorable doodle of a cartoon rat.'},
#   {'author': 'Mindy Weisberger',
#    'datetime': '2020-01-25T12:43:24Z',
#    'headline': 'Doomsday Clock is now 100 seconds from midnight',
#    'synopsis': 'A hypothetical timepiece called the Doomsday Clock measures our nearness to Armageddon — by nuclear weapons, climate change and other global threats.'},
#   {'author': 'Adam Mann',
#    'datetime': '2020-01-25T12:06:52Z',
#    'headline': 'To find intelligent alien life, humans may need to start thinking like an extraterrestrial',
#    'synopsis': 'Anthropologist reveals a potentially big flaw in the Search for Extraterrestrial Intelligence (SETI).'}],
#  'page 5': [{'author': 'Elizabeth Howell',
#    'datetime': '2020-01-25T12:03:39Z',
#    'headline': "Patrick Stewart invites Whoopi Goldberg to reprise her TNG Guinan role 'Star Trek: Picard'!",
#    'synopsis': 'Actress Whoopi Goldberg accepted an invitation to reprise her "Star Trek" role as Guinan — while on camera, in front of a live studio audience.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-25T11:50:15Z',
#    'headline': "You can watch two astronauts take a spacewalk to fix a $2 billion space experiment today. Here's how.",
#    'synopsis': "NASA plans to send a pair of astronauts on a spacewalk, one more time, to finish fixing a complicated science experiment today (Jan. 25). Here's how to watch it live."},
#   {'author': 'Doris Elin Urrutia',
#    'datetime': '2020-01-25T04:41:03Z',
#    'headline': 'Space photos: The most amazing images this week!',
#    'synopsis': 'Here are our picks for the most amazing space photos of the week.'},
#   {'author': 'Doris Elin Urrutia',
#    'datetime': '2020-01-24T22:11:40Z',
#    'headline': 'The top space stories of the week!',
#    'synopsis': 'These are the top space stories this week from Space.com.'},
#   {'author': 'Hanneke Weitering',
#    'datetime': '2020-01-24T21:49:52Z',
#    'headline': 'Félicette has landed! Memorial for first cat in space unveiled in France.',
#    'synopsis': 'A new memorial for Félicette, the first and only cat to go to space, has arrived at its permanent home at the International Space University in Strasbourg, France.'},
#   {'author': 'Brandon Specktor',
#    'datetime': '2020-01-24T21:18:55Z',
#    'headline': "A TV satellite is about to explode following 'irreversible' battery damage",
#    'synopsis': 'A Boeing satellite is being hastily moved into "graveyard orbit" following a devastating "anomaly" that turned its batteries into bombs.'},
#   {'author': 'Ravi Sharma',
#    'datetime': '2020-01-24T19:00:31Z',
#    'headline': "How India's moon crash wasn't really a failure (op-ed)",
#    'synopsis': "When India's Vikram lander crashed into the moon in September, it was a significant setback for India's lunar exploration plans — but it wasn't really a failure. Here's why."},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-24T17:31:55Z',
#    'headline': 'Four new US spaceships may start launching people into space this year',
#    'synopsis': "SpaceX's Crew Dragon capsule isn't the only vehicle in the home stretch toward crewed flight; three other private spacecraft may get up and running this year as well."},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-24T17:19:35Z',
#    'headline': "SpaceX will launch a 4-ton satellite for Egypt's Nilesat in 2022",
#    'synopsis': 'Nilesat, an Egyptian satellite operator, has partnered with SpaceX to launch a new communications satellite.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-24T16:51:55Z',
#    'headline': "The Borg return in 'Star Trek: Picard'! Jeri Ryan and Jonathan Del Arco talk 'Seven of Nine' and 'Hugh'",
#    'synopsis': 'The infamous "Star Trek" alien species the Borg, which assimilate all beings they come across into their collective consciousness, will make an appearance in the new series "Star Trek: Picard."'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-24T12:21:30Z',
#    'headline': "Fancy a ride on a space plane? Maybe AstroClipper will be what you're looking for.",
#    'synopsis': 'Startup Exodus Space Corp. plans to build a space plane to ferry cargo around Earth. Eventually, that cargo could include people, if the spacecraft is deemed safe enough.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-24T12:15:21Z',
#    'headline': "NASA's Mars rover Curiosity had an attitude problem. (But it's fine now.)",
#    'synopsis': "An attitude problem sidelined NASA's Mars rover Curiosity recently, but the robot's handlers whipped it back into shape in short order."},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-24T12:14:50Z',
#    'headline': 'Houston, we have a bake-off! We finally know what happens when you bake cookies in space',
#    'synopsis': 'It turns out that, even in space, freshly baked chocolate-chip cookies smell incredible.'},
#   {'author': 'Tariq Malik',
#    'datetime': '2020-01-24T11:58:07Z',
#    'headline': 'SpaceX delays launch of next 60 Starlink satellite due to bad weather',
#    'synopsis': 'SpaceX has postponed the launch of its next Starlink satellite constellation mission by three days, with liftoff now set for Monday, Jan. 27.'},
#   {'author': 'Scott Snowden',
#    'datetime': '2020-01-23T21:24:24Z',
#    'headline': "'Star Trek: Picard' warps onto TV with an okay premiere episode",
#    'synopsis': 'While "Star Trek" fans worldwide are rejoicing at the return of Capt. Jean-Luc Picard, the actor who plays him says his younger self would have been surprised to reprise the role.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-23T20:39:11Z',
#    'headline': 'DARPA scraps XS-1 military space plane project after Boeing drops out',
#    'synopsis': "Boeing has withdrawn from Experimental Spaceplane, a U.S. Defense Advanced Research Projects Agency (DARPA) program designed to increase the nation's access to space."},
#   {'author': 'Charles Q. Choi',
#    'datetime': '2020-01-23T19:46:34Z',
#    'headline': 'The mystery behind a superbright supernova may just have been solved',
#    'synopsis': 'The explosion likely occurred within a dense shell of matter shed by a companion star.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-23T19:22:35Z',
#    'headline': 'SpaceX may try to catch Crew Dragon capsules with a giant net. (No, really.)',
#    'synopsis': "SpaceX's Crew Dragon astronaut taxis may not always cap their missions with ocean splashdowns."},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-23T19:18:16Z',
#    'headline': "'Terminator Tape' did its job in space-junk test — and it will be back",
#    'synopsis': 'One technique that could help alleviate the space-junk scourge just passed a key off-Earth test.'},
#   {'author': 'Scott Snowden',
#    'datetime': '2020-01-23T13:39:29Z',
#    'headline': "A complete guide to what 'Star Trek' to watch before 'Star Trek: Picard'",
#    'synopsis': 'Ready your away team and set phasers to flashback. Here\'s our essential Trek viewing guide for "Star Trek: Picard!"'}],
#  'page 6': [{'author': 'Andrew Jones',
#    'datetime': '2020-01-23T12:19:30Z',
#    'headline': 'China readies its new deep-space crew capsule for 1st test flight',
#    'synopsis': 'A Chinese next-generation spacecraft for taking astronauts to low Earth orbit and beyond has arrived at a coastal spaceport in preparation for a test flight.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-23T11:58:15Z',
#    'headline': "'Star Trek: Picard': Why does Trek endure? TNG's Marina Sirtis and Brent Spiner explain",
#    'synopsis': 'Something is keeping "Star Trek: The Next Generation" going a generation after fans first met the characters. Here\'s what the actors think it is.'},
#   {'author': 'Tariq Malik',
#    'datetime': '2020-01-23T11:49:52Z',
#    'headline': 'Elon Musk is a genius, Trump says',
#    'synopsis': "'He likes rockets,' the president said."},
#   {'author': 'Robert Z. Pearlman',
#    'datetime': '2020-01-22T22:38:07Z',
#    'headline': 'Northrop Grumman names Cygnus spacecraft for first African American astronaut',
#    'synopsis': 'The first African American to be selected as an astronaut is being remembered with the naming of a space station cargo capsule set to launch during Black History Month.'},
#   {'author': 'Space.com Staff',
#    'datetime': '2020-01-22T20:29:05Z',
#    'headline': "In photos: SpaceX's amazing Crew Dragon in-flight abort test launch",
#    'synopsis': 'SpaceX successfully conducted an in-flight abort test of its Crew Dragon crew capsule on Jan. 19 to test the emergency escape system for astronauts. See photos of the test here!'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-22T20:00:52Z',
#    'headline': "Why 'Picard' symbolizes hope for 'Star Trek's' Patrick Stewart",
#    'synopsis': 'While "Star Trek" fans worldwide are rejoicing at the return of Capt. Jean-Luc Picard, the actor who plays him says his younger self would have been surprised to reprise the role.'},
#   {'author': 'Meghan Bartels',
#    'datetime': '2020-01-22T19:47:24Z',
#    'headline': "It's time to say goodbye to NASA's Spitzer Space Telescope. Here's why.",
#    'synopsis': "How does NASA know it's time to end a mission? For the Spitzer Space Telescope, the agency can blame it on the spacecraft's juice."},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-22T18:09:21Z',
#    'headline': "These photos of SpaceX's Crew Dragon abort launch are just stunning",
#    'synopsis': "This past Sunday (Jan. 19), SpaceX's Crew Dragon took off and flew brilliantly through a high-altitude test of its launch escape system."},
#   {'author': 'Space.com Staff',
#    'datetime': '2020-01-22T17:05:26Z',
#    'headline': 'This week on the Space.com forums: Seek knowledge, ask questions, win prizes!',
#    'synopsis': "If you haven't signed up for the Space.com forums yet, now is a great time, as there's a ton of things to get involved in."},
#   {'author': 'Rafi Letzter',
#    'datetime': '2020-01-22T17:00:49Z',
#    'headline': "Ancient Australian crystals unlock history of Earth's first magnetic field",
#    'synopsis': 'It was a lot more powerful than anyone believed.'},
#   {'author': 'George Marston',
#    'datetime': '2020-01-22T16:00:58Z',
#    'headline': "Taika Waititi in talks to direct 'Star Wars' film — report",
#    'synopsis': 'Thor: Ragnarok director Taika Waititi may get his chance to direct a Star Wars film soon.'},
#   {'author': 'Jesse Emspak',
#    'datetime': '2020-01-22T15:30:56Z',
#    'headline': "January new moon 2020: Catch Venus, Jupiter and more in the 'moonless' night sky",
#    'synopsis': 'In January, the moon will make a close approach to several planets both before and after it enters its new phase on Jan. 24, offering some fine photo opportunities in a bright winter sky.'},
#   {'author': 'Brandon Specktor',
#    'datetime': '2020-01-22T15:00:42Z',
#    'headline': 'Self-destructing dark matter may be flooding the sky with gamma-rays, study suggests',
#    'synopsis': "There's a faint gamma-ray background in the universe, and scientists now think it could be caused by dark matter."},
#   {'author': 'Joe Rao',
#    'datetime': '2020-01-22T12:15:36Z',
#    'headline': "How the 'comet of the century' became an astronomical disappointment",
#    'synopsis': 'Christened for months as "The Comet of the Century," Comet Kohoutek never came remotely close to living up to expectations.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-22T11:31:11Z',
#    'headline': 'Solar Orbiter, a new mission to the sun by Europe and NASA, to launch next month',
#    'synopsis': 'Solar Orbiter, a mission led by the European Space Agency with NASA participation, is scheduled to launch on Feb. 5 from Cape Canaveral Air Force Station in Florida.'},
#   {'author': 'Yasemin Saplakoglu',
#    'datetime': '2020-01-22T11:04:01Z',
#    'headline': "A burst of gravitational waves hit our planet. Astronomers have no clue where it's from.",
#    'synopsis': 'The signal doesn’t seem to match the most obvious causes.'},
#   {'author': 'Andrew Jones',
#    'datetime': '2020-01-22T10:56:13Z',
#    'headline': "China releases huge batch of amazing Chang'e-4 images from moon's far side",
#    'synopsis': "China's long-lived lunar robots Chang'e-4 and Yutu-2 are once again at work on the far side of the moon, where they woke up for their 14th day on Jan. 18 and 19."},
#   {'author': 'Amy Thompson',
#    'datetime': '2020-01-21T21:36:39Z',
#    'headline': "SpaceX's Crew Dragon abort test was 'picture-perfect,' Elon Musk says",
#    'synopsis': 'SpaceX\'s high-altitude test of its Crew Dragon launch escape system on Sunday morning (Jan. 19) appears to have been a "picture-perfect mission," company founder and CEO Elon Musk said.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-21T20:18:47Z',
#    'headline': "NASA's next Mars rover will get one of these 9 names",
#    'synopsis': 'NASA has chosen nine finalists in the student naming contest for its next Mars rover, which currently goes by the bland Mars 2020.'},
#   {'author': 'Amy Thompson',
#    'datetime': '2020-01-21T20:10:11Z',
#    'headline': "SpaceX's Crew Dragon returns to shore after successful abort test (photos)",
#    'synopsis': "SpaceX's Crew Dragon capsule returned to port Sunday night (Jan. 19), hours after it flawlessly executed a test of its built-in, launch-escape system and splashed down in the Atlantic Ocean."}],
#  'page 7': [{'author': 'Laura Geggel',
#    'datetime': '2020-01-21T18:00:13Z',
#    'headline': "Early 'soda lakes' may have provided missing ingredient key to the origin of life",
#    'synopsis': 'How did early life get its start, given that this essential mineral was scarce?'},
#   {'author': 'Paul Sutter',
#    'datetime': '2020-01-21T17:00:07Z',
#    'headline': 'The quantum world may have a favorite flavor, tantalizing results suggest',
#    'synopsis': "The world of the teensy-tiny, the quantum realm, could have a favorite flavor. Here's why that's a big deal."},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-21T16:38:18Z',
#    'headline': "Earth's oldest known impact crater may tell us a lot about our planet's frozen past",
#    'synopsis': 'Scientists have identified the oldest known impact crater on Earth — and the ancient structure could tell us how our planet emerged from a long-ago frozen phase.'},
#   {'author': 'Mindy Weisberger',
#    'datetime': '2020-01-21T16:22:53Z',
#    'headline': "Were Alien Secrets Hidden in Roswell and Area 51? 'Project Blue Book' UFO Hunters Investigate.",
#    'synopsis': 'A search for the truth behind UFO sightings leads to the discovery of government cover-ups.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-21T16:00:09Z',
#    'headline': 'Can this new model predict which alien worlds could support life?',
#    'synopsis': "It's a tough job to figure out which planets are potentially habitable, because we can only see so much detail in our telescopes."},
#   {'author': 'Robert Z. Pearlman',
#    'datetime': '2020-01-21T15:38:31Z',
#    'headline': 'Three history-making space fliers to enter Astronaut Hall of Fame in May',
#    'synopsis': 'Record-setting spacewalker Michael Lopez-Alegria, space shuttle commander Pamela Melroy and Scott Kelly, who logged the longest U.S. spaceflight, will be inducted into the Astronaut Hall of Fame.'},
#   {'author': 'Robert Z. Pearlman',
#    'datetime': '2020-01-21T15:11:54Z',
#    'headline': 'Lego is launching an International Space Station model for sale',
#    'synopsis': 'The International Space Station is about to launch into the Lego universe. It hits store shelves Feb. 1, 2020.'},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-21T15:00:14Z',
#    'headline': "NYC's Hayden Planetarium show 'Worlds Beyond Earth' is stunning and poignant",
#    'synopsis': ''},
#   {'author': 'Amy Thompson',
#    'datetime': '2020-01-21T12:09:34Z',
#    'headline': 'SpaceX gears up for next Starlink satellite megaconstellation launch with rocket test',
#    'synopsis': "SpaceX has fired up the rocket booster that will ferry the company's fourth batch of Starlink satellites into space."},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-21T12:00:21Z',
#    'headline': 'After an asteroid wiped out the dinosaurs, volcanic eruption may have helped life flourish on Earth',
#    'synopsis': ''},
#   {'author': 'Tom Metcalfe',
#    'datetime': '2020-01-21T11:51:55Z',
#    'headline': "Strange 'martian' mineral mounds rise up from Utah's Great Salt Lake",
#    'synopsis': "Rare mounds of a crystalline mineral have emerged above the surface of Utah's Great Salt Lake, where they're expected to remain just a few months before disappearing again."},
#   {'author': 'Tariq Malik',
#    'datetime': '2020-01-21T11:38:47Z',
#    'headline': 'Excited for space in 2020? Join an AMA with Editor-in-Chief Tariq Malik in our Space.com Forums!',
#    'synopsis': 'What burning space 2020 question do you have?'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-21T11:30:34Z',
#    'headline': "'Orange dwarfs' may be the best stars to study in search for life",
#    'synopsis': 'Move over, red dwarfs. Emerging research shows that another star type could be more friendly to life.'},
#   {'author': 'Robert Z. Pearlman',
#    'datetime': '2020-01-21T02:30:57Z',
#    'headline': 'Astronauts honor Martin Luther King, Jr. and replace ISS batteries on 3rd all-woman spacewalk',
#    'synopsis': ''},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-21T01:15:55Z',
#    'headline': "An all-woman Mars analog crew just 'returned to Earth' in Hawaii",
#    'synopsis': 'An all-female crew of analog astronauts have "returned to Earth," completing a two-week mission in a mock Mars habitat on the big island of Hawaii.'},
#   {'author': 'Peter Vickers',
#    'datetime': '2020-01-20T12:44:48Z',
#    'headline': 'Alien life is out there. But our theories are steering us away from it.',
#    'synopsis': 'Alien life is out there, but our current theories seem to be steering us away from it, says this scientist.'},
#   {'author': 'Leonard David',
#    'datetime': '2020-01-20T12:17:01Z',
#    'headline': 'Are the aliens us? UFOs may be piloted by time-traveling humans, book argues',
#    'synopsis': 'The great distances covered by visiting "aliens" may be ones of time rather than space, a recent book argues.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-20T12:12:04Z',
#    'headline': "Spacewalking astronauts are upgrading the space station today. Here's how to watch it live.",
#    'synopsis': 'Two NASA astronauts are taking a spacewalk outside the International Space Station today (Jan. 15), and you can watch all the action live online.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-19T20:35:30Z',
#    'headline': 'SpaceX aims to launch astronauts this spring after Crew Dragon escape test success',
#    'synopsis': "The first crewed flight of SpaceX's new astronaut taxi is likely just a few months away, now that a critical safety test is in the rearview mirror."},
#   {'author': 'Hanneke Weitering',
#    'datetime': '2020-01-19T20:27:51Z',
#    'headline': "See the moon, Mars and Antares form a triangle in Monday's predawn sky",
#    'synopsis': 'The waning crescent moon will form a triangle with the Red Planet and the bright star Antares in the morning sky on Monday (Jan. 20), and you can catch the trio in the morning sky before dawn.'}],
#  'page 8': [{'author': 'Amy Thompson',
#    'datetime': '2020-01-19T16:28:11Z',
#    'headline': 'SpaceX aces Crew Dragon launch abort test, destroys rocket on purpose',
#    'synopsis': "SpaceX just took a giant leap in its quest to launch astronauts, successfully showcasing the Crew Dragon capsule's launch escape system during flight."},
#   {'author': 'Tariq Malik',
#    'datetime': '2020-01-19T14:38:09Z',
#    'headline': "How SpaceX's Crew Dragon launch abort test today works in 10 not-so-easy steps",
#    'synopsis': 'SpaceX will launch its Crew Dragon spacecraft on a critical abort test Saturday morning (Jan. 18), and you can watch it live online.'},
#   {'author': 'Meghan Bartels',
#    'datetime': '2020-01-19T12:16:22Z',
#    'headline': 'The Spitzer Space Telescope will shut down Jan. 30. NASA celebrates its legacy this week.',
#    'synopsis': 'A 16-year NASA mission that painted the universe in infrared light will come to an end this month, as the Spitzer Space Telescope takes its final observations on Jan. 29.'},
#   {'author': 'Amy Thompson',
#    'datetime': '2020-01-18T15:47:17Z',
#    'headline': 'SpaceX delays Crew Dragon abort test launch to Sunday due to bad weather',
#    'synopsis': 'SpaceX has postponed the launch of a major astronaut safety test of its Crew Dragon spacecraft to Sunday, Jan. 19, due to bad weather at the launch and recovery sites.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-18T15:00:12Z',
#    'headline': "Meet Mal Reynolds' mom in 'Firefly: The Outlaw Ma Reynolds' (preview)",
#    'synopsis': 'Fans of Captain Malcolm Reynolds in the science fiction TV show "Firefly" now have a glimpse of his family history — in comic form.'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-18T13:31:58Z',
#    'headline': "'Firefly: The Unification War Vol. 2' reveals Mal Reynolds' military past",
#    'synopsis': 'Browncoats, it\'s finally here — the next chapter of the Unification War of the "Firefly" sci-fi franchise in a new comic from creator Joss Whedon and others.'},
#   {'author': 'Scott Snowden',
#    'datetime': '2020-01-18T12:12:06Z',
#    'headline': "'Star Trek: Picard' world premiere draws huge crowds and sci-fi stars",
#    'synopsis': 'O Captain! my Captain! Sir Patrick Stewart reprises his iconic role as Jean-Luc Picard in the latest spin-off series in the "Star Trek" universe.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-18T12:01:13Z',
#    'headline': "Elon Musk is still thinking big with SpaceX's Starship Mars-colonizing rocket. Really big.",
#    'synopsis': "Elon Musk outlined some ambitious goals for SpaceX's Starship Mars-colonization system during a flurry of Twitter posts on Thursday (Jan. 16)."},
#   {'author': 'Amy Thompson',
#    'datetime': '2020-01-18T11:52:18Z',
#    'headline': "How to watch SpaceX's Crew Dragon abort test live online this Sunday",
#    'synopsis': 'SpaceX will launch its Crew Dragon spacecraft on a critical abort test Sunday morning (Jan. 19), and you can watch it live online.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-17T21:31:53Z',
#    'headline': "SpaceX, NASA 'go' for major Crew Dragon launch escape test Saturday",
#    'synopsis': "SpaceX's new astronaut taxi is ready to showcase its safety features in a critical flight test tomorrow (Jan. 18) that will help pave the way for the vehicle's first crewed flight."},
#   {'author': 'Doris Elin Urrutia',
#    'datetime': '2020-01-17T17:15:24Z',
#    'headline': 'High school student discovers alien planet with twin suns just days into a NASA internship',
#    'synopsis': 'A high school junior found a distant planet that orbits two stars, one of just a dozen such worlds known to scientists.'},
#   {'author': 'Meghan Bartels',
#    'datetime': '2020-01-17T17:00:11Z',
#    'headline': 'How the tiny exoplanet-hunting ASTERIA satellite showed scientists what cubesats can do',
#    'synopsis': 'A tiny satellite studying alien worlds may be gone for good, but during the two years the spacecraft operated, it laid the foundation for what may become a new way of finding exoplanets.'},
#   {'author': 'Amy Thompson',
#    'datetime': '2020-01-17T16:06:36Z',
#    'headline': "SpaceX is about to destroy a rocket in a critical Crew Dragon test flight. Here's why.",
#    'synopsis': 'On Saturday, Jan. 18, SpaceX will intentionally destroy one of its rockets in the name of safety.'},
#   {'author': 'Yasemin Saplakoglu',
#    'datetime': '2020-01-17T12:06:01Z',
#    'headline': 'Violent solar storms are happening closer to Earth than anyone thought was possible',
#    'synopsis': 'The spectacular solar storms that paint the polar skies in beautiful greens and pinks have a darker side'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-17T12:04:25Z',
#    'headline': "What will NASA's Mars 2020 rover be called? There's 155 names on the shortlist.",
#    'synopsis': "The competition to name NASA's next Mars rover has entered a new phase, with the space agency culling the field from 28,000 down to 155."},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-17T11:59:49Z',
#    'headline': "Milky Way's cannibalistic past illuminated by ancient star's life story",
#    'synopsis': "A planet-hunting telescope recently made a new discovery about the Milky Way's past cannibalism."},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-17T11:47:55Z',
#    'headline': 'Stealth space startup SpinLaunch snares another $35 million from investors',
#    'synopsis': "The company's total investment haul is now $80 million."},
#   {'author': 'Robert Z. Pearlman',
#    'datetime': '2020-01-16T23:06:08Z',
#    'headline': "Astronaut joins Olay's star-studded Super Bowl ad to 'make space for women'",
#    'synopsis': 'A former NASA astronaut is starring in a Super Bowl ad to help "make space for women."'},
#   {'author': 'Elizabeth Howell',
#    'datetime': '2020-01-16T22:42:08Z',
#    'headline': 'NASA astronaut Christina Koch celebrates her 300th day in space',
#    'synopsis': 'NASA astronaut Christina Koch has smashed another gender barrier. Koch recently surpassed her 300th consecutive day in space, which is the longest for any woman.'},
#   {'author': 'Hanneke Weitering',
#    'datetime': '2020-01-16T22:16:34Z',
#    'headline': 'In photos: Ariane 5 rocket lofts 2 satellites into orbit for Eutelsat, India',
#    'synopsis': 'In its first launch of the year, Arianespace successfully used an Ariane 5 rocket to launch two new communications satellites into orbit for Eutelsat and India. See photos of the mission here!'}],
#  'page 9': [{'author': 'Elizabeth Howell',
#    'datetime': '2020-01-16T21:44:56Z',
#    'headline': 'Ariane 5 rocket launches communications satellites for India, Eutelsat into orbit',
#    'synopsis': 'Arianespace flew a pair of communications satellites safely into space Thursday (Jan. 16) during its first launch of 2020.'},
#   {'author': 'Samantha Mathewson',
#    'datetime': '2020-01-16T19:22:20Z',
#    'headline': 'Huge Philippines volcano eruption blasts ash 9 miles up as satellites watch (video)',
#    'synopsis': 'The Taal volcano eruption in the Philippines this week sent ash plumes 9 miles (14 kilometers) into the air, new satellite imagery shows.'},
#   {'author': 'Rafi Letzter',
#    'datetime': '2020-01-16T18:00:15Z',
#    'headline': "This super-sharp image could help explain the Milky Way's strange creamy center",
#    'synopsis': "What's going on in the middle of our galaxy?"},
#   {'author': 'Hanneke Weitering',
#    'datetime': '2020-01-16T17:17:48Z',
#    'headline': 'An Ariane 5 rocket will launch 2 communications satellites today. How to watch live',
#    'synopsis': 'The European launch provider Arianespace will use an Ariane 5 rocket to launch two new communications satellites into orbit today (Jan. 16), and you can watch it live online.'},
#   {'author': 'Michael D. Shaw',
#    'datetime': '2020-01-16T17:00:48Z',
#    'headline': 'Astronauts and addiction: Ending the stigma (op-ed)',
#    'synopsis': 'Astronauts sometimes face the gravest threats after they return to Earth. Facing depression, alcoholism and substance abuse in general, astronauts are not immune from addiction.'},
#   {'author': 'Andrew Jones',
#    'datetime': '2020-01-16T17:00:32Z',
#    'headline': 'China lofts 4 satellites into orbit with its second launch of 2020',
#    'synopsis': "China successfully sent four satellites into orbit early on Wednesday (Jan. 15) with the country's second launch of 2020."},
#   {'author': 'Meghan Bartels',
#    'datetime': '2020-01-16T15:31:34Z',
#    'headline': '2019 was the second hottest year on record, NASA says',
#    'synopsis': "It's the award no one wanted to win: 2019 was the second hottest year on record, government scientists confirmed yesterday (Jan. 15)."},
#   {'author': 'Amy Thompson',
#    'datetime': '2020-01-16T12:25:23Z',
#    'headline': 'Sierra Nevada eyes 2021 launch of Dream Chaser space plane',
#    'synopsis': 'Dream Chaser may get off the ground next year.'},
#   {'author': 'Meghan Bartels',
#    'datetime': '2020-01-16T12:05:57Z',
#    'headline': 'Controversy over giant telescope roils astronomy conference in Hawaii',
#    'synopsis': "Heated conversations at the American Astronomical Society's January meeting are usually about stars and galaxies, distant worlds and elaborate calculations."},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-16T11:57:53Z',
#    'headline': "Moon 'shrooms? Fungi eyed to help build lunar bases and Mars outposts",
#    'synopsis': ''},
#   {'author': 'Samantha Mathewson',
#    'datetime': '2020-01-16T11:00:23Z',
#    'headline': "Why are black holes just 'wandering' on the outskirts of their dwarf galaxies?",
#    'synopsis': 'Several supermassive black holes have been found wandering through their dwarf host galaxies, offering new clues about how similar black holes evolved in the early universe.'},
#   {'author': 'Robert Z. Pearlman',
#    'datetime': '2020-01-15T22:41:00Z',
#    'headline': "New Boeing video shows Snoopy's ride on Starliner Orbital Flight Test",
#    'synopsis': 'Snoopy\'s latest adventure as the "world famous astronaut" has now been revealed in a new video from the first Orbital Flight Test of Boeing\'s CST-100 Starliner.'},
#   {'author': 'Doris Elin Urrutia',
#    'datetime': '2020-01-15T22:00:54Z',
#    'headline': 'Tour the colorful Crab Nebula with this stunning new 3D visualization',
#    'synopsis': 'A new 3D movie highlights the Crab Nebula, beginning with its location in the constellation Taurus and zooming in to show off its dynamic features.'},
#   {'author': 'Robert Z. Pearlman',
#    'datetime': '2020-01-15T21:09:04Z',
#    'headline': 'Astronauts upgrade space station batteries in second all-woman spacewalk',
#    'synopsis': 'The second all-female spacewalk in history continued the work of the first, as NASA astronauts Jessica Meir and Christina Koch upgraded batteries outside of the International Space Station.'},
#   {'author': 'Brandon Specktor',
#    'datetime': '2020-01-15T21:07:00Z',
#    'headline': 'The black hole at the center of the galaxy is forging a strange new kind of star',
#    'synopsis': 'The black hole at the center of our galaxy is warping and combining stars into a strange new kind of object, astronomers say.'},
#   {'author': 'Doris Elin Urrutia',
#    'datetime': '2020-01-15T21:00:40Z',
#    'headline': "Scientists study plasma 'bubbles' in Earth's magnetic field with Gamera model named for Japanese monster",
#    'synopsis': "Auroras and satellite function might be influenced by ''bubbles'' of plasma near the tail of Earth's magnetosphere."},
#   {'author': 'Chelsea Gohd',
#    'datetime': '2020-01-15T20:00:53Z',
#    'headline': "Astronomers just tracked the interstellar journey of one of life's building blocks through space",
#    'synopsis': 'Scientists have traced the journey of phosphorous, one of the essential building blocks for life as we know it on Earth, through space.'},
#   {'author': 'Mike Wall',
#    'datetime': '2020-01-15T19:03:51Z',
#    'headline': "Proxima Centauri, the sun's nearest neighbor, may host a 2nd alien planet. Meet Proxima c.",
#    'synopsis': 'Astronomers have spotted another possible planet orbiting Proxima Centauri, which lies just 4.2 light-years from the sun.'},
#   {'author': 'Samantha Rolfe',
#    'datetime': '2020-01-15T18:00:32Z',
#    'headline': 'Could invisible aliens really exist among us? An astrobiologist explains',
#    'synopsis': 'Alien lifeforms are impossible to spot.'},
#   {'author': 'Doris Elin Urrutia',
#    'datetime': '2020-01-15T17:32:54Z',
#    'headline': "Giant 'Rubin's Galaxy' stars in stunning Hubble photo named for dark matter pioneer",
#    'synopsis': 'Two cosmic love birds lit the way to the discovery of dark matter, and a new Hubble image features a behemoth galaxy that played a part in the groundbreaking finding.'}]}
